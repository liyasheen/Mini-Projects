# %% [markdown]
# Basic Calculator

# %%
def add(x,y):
    return x+y
def minus(x,y):
    return x-y
def multiply(x,y):
    return x*y
def divide(x,y):
    return x/y

while True:
    while True:
        try:
            a=input()
            x=float(a)
            break
        except ValueError:
            print("Error. Enter a number")

    while True:
        function=input()
        b=str(function)
        if b=="*":
                break
        elif b=="/":
                break
        elif b=="+":
                break
        elif b=="-":
                break
        else:
            print("Please choose *, +, / or -")

    while True:
        try:
            c=input()
            y=float(c)
            break
        except ValueError:
            print("Error. Enter a number")


    if b=="*":
        print(multiply(x,y))
    if b=="/":
        print(divide(x,y))
    if b=="+":
        print(add(x,y))
    if b=="-":
        print(minus(x,y))
        
    print("Press return to start new calculation")
    new=input()
    print("Loading...")
    print("")
    import time
    time.sleep(3)
    try:
        float(b)
    except ValueError:
        print("---NEW CALCULATION---")
# Out:
# 29
# +
# 30
# 59.0
# Press return to start new calculation
#
# Loading...
#
# ---NEW CALCULATION---
# a
# Error. Enter a number
# 20
# s
# Please choose *, +, / or -
# /
# 5
# 4.0
# Press return to start new calculation
